# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
data = pd.read_csv('/content/drive/My Drive/labeled_lyrics_cleaned.csv')
data
# Out:
#         Unnamed: 0        artist  \
# 0                0  Elijah Blake
# 1                1  Elijah Blake
# 2                2  Elijah Blake
# 3                3  Elijah Blake
# 4                4  Elijah Blake
# ...            ...           ...
# 158348      158348    Adam Green
# 158349      158349    Adam Green
# 158350      158350    Adam Green
# 158351      158351    Adam Green
# 158352      158352    Adam Green
#
#                                                       seq                song  \
# 0       No, no\r\nI ain't ever trapped out the bando\r...            Everyday
# 1       The drinks go down and smoke goes up, I feel m...    Live Till We Die
# 2       She don't live on planet Earth no more\r\nShe ...       The Otherside
# 3       Trippin' off that Grigio, mobbin', lights low\...               Pinot
# 4       I see a midnight panther, so gallant and so br...  Shadows & Diamonds
# ...                                                   ...                 ...
# 158348  And we live on borrowed time,\r\nBut this head...     Friends of Mine
# 158349  Frozin in time forever\r\nCarrying that torch ...      Frozen in Time
# 158350  Hard to be a girl. \r\nSo nice to be a boy. \r...   Hard to Be a Girl
# 158351  I want to chose to die,\r\nAnd be buried with ...         I Wanna Die
# 158352  Musical ladders\r\nLeaning on mountains\r\nBat...     Musical Ladders
#
#         label
# 0       0.626
# 1       0.630
# 2       0.240
# 3       0.536
# 4       0.371
# ...       ...
# 158348  0.737
# 158349  0.482
# 158350  0.733
# 158351  0.361
# 158352  0.263
#
# [158353 rows x 5 columns]

# %%
data.isnull().sum() #결측치없음
# Out:
# Unnamed: 0    0
# artist        0
# seq           0
# song          0
# label         0
# dtype: int64

# %%
data.drop('Unnamed: 0', axis=1, inplace=True) # 인덱스 열 제거
data.rename(columns={'seq':'lyrics'}, inplace= True) # 가사 열 이름 변경

# %% [markdown]
# 전처리

# %%
# 가사 토큰화
data['lyrics'] = data['lyrics'].str.lower() #가사 소문자로변경
data['lyrics'] = data['lyrics'].str.replace(',','') # 가사 콤마 제거

# %%
data
# Out:
#               artist                                             lyrics  \
# 0       Elijah Blake  no no\r\ni ain't ever trapped out the bando\r\...
# 1       Elijah Blake  the drinks go down and smoke goes up i feel my...
# 2       Elijah Blake  she don't live on planet earth no more\r\nshe ...
# 3       Elijah Blake  trippin' off that grigio mobbin' lights low\r\...
# 4       Elijah Blake  i see a midnight panther so gallant and so bra...
# ...              ...                                                ...
# 158348    Adam Green  and we live on borrowed time\r\nbut this heads...
# 158349    Adam Green  frozin in time forever\r\ncarrying that torch ...
# 158350    Adam Green  hard to be a girl. \r\nso nice to be a boy. \r...
# 158351    Adam Green  i want to chose to die\r\nand be buried with a...
# 158352    Adam Green  musical ladders\r\nleaning on mountains\r\nbat...
#
#                       song  label
# 0                 Everyday  0.626
# 1         Live Till We Die  0.630
# 2            The Otherside  0.240
# 3                    Pinot  0.536
# 4       Shadows & Diamonds  0.371
# ...                    ...    ...
# 158348     Friends of Mine  0.737
# 158349      Frozen in Time  0.482
# 158350   Hard to Be a Girl  0.733
# 158351         I Wanna Die  0.361
# 158352     Musical Ladders  0.263
#
# [158353 rows x 4 columns]

# %%
#표제어(Lemma) 추출 - 기본 사전형 단어를 추출
from nltk.stem import WordNetLemmatizer 
lemmatizer = WordNetLemmatizer()

# %%
# 표제화 함수 생성
def lemmatize_words(text):
    words = text.split()
    words = [lemmatizer.lemmatize(word,pos='v') for word in words]
    return ' '.join(words)

# %%
import nltk
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
data['lem'] = data['lyrics'].apply(lemmatize_words)

# %%
data['lem'] = data['lem'].str.replace(pat=r'\(.*\)|\s-\s.*', repl=r' ', regex=True) #괄호() 가사 제거
data
# Out:
#               artist                                             lyrics  \
# 0       Elijah Blake  no no\r\ni ain't ever trapped out the bando\r\...
# 1       Elijah Blake  the drinks go down and smoke goes up i feel my...
# 2       Elijah Blake  she don't live on planet earth no more\r\nshe ...
# 3       Elijah Blake  trippin' off that grigio mobbin' lights low\r\...
# 4       Elijah Blake  i see a midnight panther so gallant and so bra...
# ...              ...                                                ...
# 158348    Adam Green  and we live on borrowed time\r\nbut this heads...
# 158349    Adam Green  frozin in time forever\r\ncarrying that torch ...
# 158350    Adam Green  hard to be a girl. \r\nso nice to be a boy. \r...
# 158351    Adam Green  i want to chose to die\r\nand be buried with a...
# 158352    Adam Green  musical ladders\r\nleaning on mountains\r\nbat...
#
#                       song  label  \
# 0                 Everyday  0.626
# 1         Live Till We Die  0.630
# 2            The Otherside  0.240
# 3                    Pinot  0.536
# 4       Shadows & Diamonds  0.371
# ...                    ...    ...
# 158348     Friends of Mine  0.737
# 158349      Frozen in Time  0.482
# 158350   Hard to Be a Girl  0.733
# 158351         I Wanna Die  0.361
# 158352     Musical Ladders  0.263
#
#                                                       lem
# 0       no no i ain't ever trap out the bando but oh l...
# 1       the drink go down and smoke go up i feel mysel...
# 2       she don't live on planet earth no more she fin...
# 3       trippin' off that grigio mobbin' light low tri...
# 4       i see a midnight panther so gallant and so bra...
# ...                                                   ...
# 158348  and we live on borrow time but this headshot's...
# 158349  frozin in time forever carry that torch for so...
# 158350  hard to be a girl. so nice to be a boy. in my ...
# 158351  i want to choose to die and be bury with a rub...
# 158352  musical ladder lean on mountains bath in white...
#
# [158353 rows x 5 columns]

# %%
data['lem'] = data['lem'].str.replace(pat=r"'", repl=r' ', regex=True) 
# Trippin' off that Grigio, mobbin', lights low 과 같은 가사들이 있어 '(따옴표) 제거

# %%
data
# Out:
#               artist                                             lyrics  \
# 0       Elijah Blake  no no\r\ni ain't ever trapped out the bando\r\...
# 1       Elijah Blake  the drinks go down and smoke goes up i feel my...
# 2       Elijah Blake  she don't live on planet earth no more\r\nshe ...
# 3       Elijah Blake  trippin' off that grigio mobbin' lights low\r\...
# 4       Elijah Blake  i see a midnight panther so gallant and so bra...
# ...              ...                                                ...
# 158348    Adam Green  and we live on borrowed time\r\nbut this heads...
# 158349    Adam Green  frozin in time forever\r\ncarrying that torch ...
# 158350    Adam Green  hard to be a girl. \r\nso nice to be a boy. \r...
# 158351    Adam Green  i want to chose to die\r\nand be buried with a...
# 158352    Adam Green  musical ladders\r\nleaning on mountains\r\nbat...
#
#                       song  label  \
# 0                 Everyday  0.626
# 1         Live Till We Die  0.630
# 2            The Otherside  0.240
# 3                    Pinot  0.536
# 4       Shadows & Diamonds  0.371
# ...                    ...    ...
# 158348     Friends of Mine  0.737
# 158349      Frozen in Time  0.482
# 158350   Hard to Be a Girl  0.733
# 158351         I Wanna Die  0.361
# 158352     Musical Ladders  0.263
#
#                                                       lem
# 0       no no i ain t ever trap out the bando but oh l...
# 1       the drink go down and smoke go up i feel mysel...
# 2       she don t live on planet earth no more she fin...
# 3       trippin  off that grigio mobbin  light low tri...
# 4       i see a midnight panther so gallant and so bra...
# ...                                                   ...
# 158348  and we live on borrow time but this headshot s...
# 158349  frozin in time forever carry that torch for so...
# 158350  hard to be a girl. so nice to be a boy. in my ...
# 158351  i want to choose to die and be bury with a rub...
# 158352  musical ladder lean on mountains bath in white...
#
# [158353 rows x 5 columns]

# %%
# 가사 토큰화 

data['cleaned_lyrics'] = data['lem'].str.split() #띄어쓰기로 나누기
data
# Out:
#               artist                                             lyrics  \
# 0       Elijah Blake  no no\r\ni ain't ever trapped out the bando\r\...
# 1       Elijah Blake  the drinks go down and smoke goes up i feel my...
# 2       Elijah Blake  she don't live on planet earth no more\r\nshe ...
# 3       Elijah Blake  trippin' off that grigio mobbin' lights low\r\...
# 4       Elijah Blake  i see a midnight panther so gallant and so bra...
# ...              ...                                                ...
# 158348    Adam Green  and we live on borrowed time\r\nbut this heads...
# 158349    Adam Green  frozin in time forever\r\ncarrying that torch ...
# 158350    Adam Green  hard to be a girl. \r\nso nice to be a boy. \r...
# 158351    Adam Green  i want to chose to die\r\nand be buried with a...
# 158352    Adam Green  musical ladders\r\nleaning on mountains\r\nbat...
#
#                       song  label  \
# 0                 Everyday  0.626
# 1         Live Till We Die  0.630
# 2            The Otherside  0.240
# 3                    Pinot  0.536
# 4       Shadows & Diamonds  0.371
# ...                    ...    ...
# 158348     Friends of Mine  0.737
# 158349      Frozen in Time  0.482
# 158350   Hard to Be a Girl  0.733
# 158351         I Wanna Die  0.361
# 158352     Musical Ladders  0.263
#
#                                                       lem  \
# 0       no no i ain t ever trap out the bando but oh l...
# 1       the drink go down and smoke go up i feel mysel...
# 2       she don t live on planet earth no more she fin...
# 3       trippin  off that grigio mobbin  light low tri...
# 4       i see a midnight panther so gallant and so bra...
# ...                                                   ...
# 158348  and we live on borrow time but this headshot s...
# 158349  frozin in time forever carry that torch for so...
# 158350  hard to be a girl. so nice to be a boy. in my ...
# 158351  i want to choose to die and be bury with a rub...
# 158352  musical ladder lean on mountains bath in white...
#
#                                            cleaned_lyrics
# 0       [no, no, i, ain, t, ever, trap, out, the, band...
# 1       [the, drink, go, down, and, smoke, go, up, i, ...
# 2       [she, don, t, live, on, planet, earth, no, mor...
# 3       [trippin, off, that, grigio, mobbin, light, lo...
# 4       [i, see, a, midnight, panther, so, gallant, an...
# ...                                                   ...
# 158348  [and, we, live, on, borrow, time, but, this, h...
# 158349  [frozin, in, time, forever, carry, that, torch...
# 158350  [hard, to, be, a, girl., so, nice, to, be, a, ...
# 158351  [i, want, to, choose, to, die, and, be, bury, ...
# 158352  [musical, ladder, lean, on, mountains, bath, i...
#
# [158353 rows x 6 columns]

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english') #불용어 사전 가져오기

# %%
# 불용어 단어 더 추가
stop.extend(["0o", "0s", "3a", "3b", "3d", "6b", "6o", "a", "a1", "a2", "a3", "a4", "ab", "able", "about", "above", "abst", "ac", "accordance", "according", "accordingly", "across", "act", "actually", "ad", "added", "adj", "ae", "af", "affected", "affecting", "affects", "after", "afterwards", "ag", "again", "against", "ah", "ain", "ain't", "aj", "al", "all", "allow", "allows", "almost", "alone", "along", "already", "also", "although", "always", "am", "among", "amongst", "amoungst", "amount", "an", "and", "announce", "another", "any", "anybody", "anyhow", "anymore", "anyone", "anything", "anyway", "anyways", "anywhere", "ao", "ap", "apart", "apparently", "appear", "appreciate", "appropriate", "approximately", "ar", "are", "aren", "arent", "aren't", "arise", "around", "as", "a's", "aside", "ask", "asking", "associated", "at", "au", "auth", "av", "available", "aw", "away", "awfully", "ax", "ay", "az", "b", "b1", "b2", "b3", "ba", "back", "bc", "bd", "be", "became", "because", "become", "becomes", "becoming", "been", "before", "beforehand", "begin", "beginning", "beginnings", "begins", "behind", "being", "believe", "below", "beside", "besides", "best", "better", "between", "beyond", "bi", "bill", "biol", "bj", "bk", "bl", "bn", "both", "bottom", "bp", "br", "brief", "briefly", "bs", "bt", "bu", "but", "bx", "by", "c", "c1", "c2", "c3", "ca", "call", "came", "can", "cannot", "cant", "can't", "cause", "causes", "cc", "cd", "ce", "certain", "certainly", "cf", "cg", "ch", "changes", "ci", "cit", "cj", "cl", "clearly", "cm", "c'mon", "cn", "co", "com", "come", "comes", "con", "concerning", "consequently", "consider", "considering", "contain", "containing", "contains", "corresponding", "could", "couldn", "couldnt", "couldn't", "course", "cp", "cq", "cr", "cry", "cs", "c's", "ct", "cu", "currently", "cv", "cx", "cy", "cz", "d", "d2", "da", "date", "dc", "dd", "de", "definitely", "describe", "described", "despite", "detail", "df", "di", "did", "didn", "didn't", "different", "dj", "dk", "dl", "do", "does", "doesn", "doesn't", "doing", "don", "done", "don't", "down", "downwards", "dp", "dr", "ds", "dt", "du", "due", "during", "dx", "dy", "e", "e2", "e3", "ea", "each", "ec", "ed", "edu", "ee", "ef", "effect", "eg", "ei", "eight", "eighty", "either", "ej", "el", "eleven", "else", "elsewhere", "em", "empty", "en", "end", "ending", "enough", "entirely", "eo", "ep", "eq", "er", "es", "especially", "est", "et", "et-al", "etc", "eu", "ev", "even", "ever", "every", "everybody", "everyone", "everything", "everywhere", "ex", "exactly", "example", "except", "ey", "f", "f2", "fa", "far", "fc", "few", "ff", "fi", "fifteen", "fifth", "fify", "fill", "find", "fire", "first", "five", "fix", "fj", "fl", "fn", "fo", "followed", "following", "follows", "for", "former", "formerly", "forth", "forty", "found", "four", "fr", "from", "front", "fs", "ft", "fu", "full", "further", "furthermore", "fy", "g", "ga", "gave", "ge", "get", "gets", "getting", "gi", "give", "given", "gives", "giving", "gj", "gl", "go", "goes", "going", "gone", "got", "gotten", "gr", "greetings", "gs", "gy", "h", "h2", "h3", "had", "hadn", "hadn't", "happens", "hardly", "has", "hasn", "hasnt", "hasn't", "have", "haven", "haven't", "having", "he", "hed", "he'd", "he'll", "hello", "help", "hence", "her", "here", "hereafter", "hereby", "herein", "heres", "here's", "hereupon", "hers", "herself", "hes", "he's", "hh", "hi", "hid", "him", "himself", "his", "hither", "hj", "ho", "home", "hopefully", "how", "howbeit", "however", "how's", "hr", "hs", "http", "hu", "hundred", "hy", "i", "i2", "i3", "i4", "i6", "i7", "i8", "ia", "ib", "ibid", "ic", "id", "i'd", "ie", "if", "ig", "ignored", "ih", "ii", "ij", "il", "i'll", "im", "i'm", "immediate", "immediately", "importance", "important", "in", "inasmuch", "inc", "indeed", "index", "indicate", "indicated", "indicates", "information", "inner", "insofar", "instead", "interest", "into", "invention", "inward", "io", "ip", "iq", "ir", "is", "isn", "isn't", "it", "itd", "it'd", "it'll", "its", "it's", "itself", "iv", "i've", "ix", "iy", "iz", "j", "jj", "jr", "js", "jt", "ju", "just", "k", "ke", "keep", "keeps", "kept", "kg", "kj", "km", "know", "known", "knows", "ko", "l", "l2", "la", "largely", "last", "lately", "later", "latter", "latterly", "lb", "lc", "le", "least", "les", "less", "lest", "let", "lets", "let's", "lf", "like", "liked", "likely", "line", "little", "lj", "ll", "ll", "ln", "lo", "look", "looking", "looks", "los", "lr", "ls", "lt", "ltd", "m", "m2", "ma", "made", "mainly", "make", "makes", "many", "may", "maybe", "me", "mean", "means", "meantime", "meanwhile", "merely", "mg", "might", "mightn", "mightn't", "mill", "million", "mine", "miss", "ml", "mn", "mo", "more", "moreover", "most", "mostly", "move", "mr", "mrs", "ms", "mt", "mu", "much", "mug", "must", "mustn", "mustn't", "my", "myself", "n", "n2", "na", "name", "namely", "nay", "nc", "nd", "ne", "near", "nearly", "necessarily", "necessary", "need", "needn", "needn't", "needs", "neither", "never", "nevertheless", "new", "next", "ng", "ni", "nine", "ninety", "nj", "nl", "nn", "no", "nobody", "non", "none", "nonetheless", "noone", "nor", "normally", "nos", "not", "noted", "nothing", "novel", "now", "nowhere", "nr", "ns", "nt", "ny", "o", "oa", "ob", "obtain", "obtained", "obviously", "oc", "od", "of", "off", "often", "og", "oh", "oi", "oj", "ok", "okay", "ol", "old", "om", "omitted", "on", "once", "one", "ones", "only", "onto", "oo", "op", "oq", "or", "ord", "os", "ot", "other", "others", "otherwise", "ou", "ought", "our", "ours", "ourselves", "out", "outside", "over", "overall", "ow", "owing", "own", "ox", "oz", "p", "p1", "p2", "p3", "pa","page", "pagecount", "pages", "par", "part", "particular", "particularly", "pas", "past", "pc", "pd", "pe", "per", "perhaps", "pf", "ph", "pi", "pj", "pk", "pl", "placed", "please", "plus", "pm", "pn", "po", "poorly", "possible", "possibly", "potentially", "pp", "pq", "pr", "predominantly", "present", "presumably", "previously", "primarily", "probably", "promptly", "proud", "provides", "ps", "pt", "pu", "put", "py", "q", "qj", "qu", "que", "quickly", "quite", "qv", "r", "r2", "ra", "ran", "rather", "rc", "rd", "re", "readily", "really", "reasonably", "recent", "recently", "ref", "refs", "regarding", "regardless", "regards", "related", "relatively", "research", "research-articl", "respectively", "resulted", "resulting", "results", "rf", "rh", "ri", "right", "rj", "rl", "rm", "rn", "ro", "rq", "rr", "rs", "rt", "ru", "run", "rv", "ry", "s", "s2", "sa", "said", "same", "saw", "say", "saying", "says", "sc", "sd", "se", "sec", "second", "secondly", "section", "see", "seeing", "seem", "seemed", "seeming", "seems", "seen", "self", "selves", "sensible", "sent", "serious", "seriously", "seven", "several", "sf", "shall", "shan", "shan't", "she", "shed", "she'd", "she'll", "shes", "she's", "should", "shouldn", "shouldn't", "should've", "show", "showed", "shown", "showns", "shows", "si", "side", "significant", "significantly", "similar", "similarly", "since", "sincere", "six", "sixty", "sj", "sl", "slightly", "sm", "sn", "so", "some", "somebody", "somehow", "someone", "somethan", "something", "sometime", "sometimes", "somewhat", "somewhere", "soon", "sorry", "sp", "specifically", "specified", "specify", "specifying", "sq", "sr", "ss", "st", "still", "stop", "strongly", "sub", "substantially", "successfully", "such", "sufficiently", "suggest", "sup", "sure", "sy", "system", "sz", "t", "t1", "t2", "t3", "take", "taken", "taking", "tb", "tc", "td", "te", "tell", "ten", "tends", "tf", "th", "than", "thank", "thanks", "thanx", "that", "that'll", "thats", "that's", "that've", "the", "their", "theirs", "them", "themselves", "then", "thence", "there", "thereafter", "thereby", "thered", "therefore", "therein", "there'll", "thereof", "therere", "theres", "there's", "thereto", "thereupon", "there've", "these", "they", "theyd", "they'd", "they'll", "theyre", "they're", "they've", "thickv", "thin", "think", "third", "this", "thorough", "thoroughly", "those", "thou", "though", "thoughh", "thousand", "three", "throug", "through", "throughout", "thru", "thus", "ti", "til", "tip", "tj", "tl", "tm", "tn", "to", "together", "too", "took", "top", "toward", "towards", "tp", "tq", "tr", "tried", "tries", "truly", "try", "trying", "ts", "t's", "tt", "tv", "twelve", "twenty", "twice", "two", "tx", "u", "u201d", "ue", "ui", "uj", "uk", "um", "un", "under", "unfortunately", "unless", "unlike", "unlikely", "until", "unto", "uo", "up", "upon", "ups", "ur", "us", "use", "used", "useful", "usefully", "usefulness", "uses", "using", "usually", "ut", "v", "va", "value", "various", "vd", "ve", "ve", "very", "via", "viz", "vj", "vo", "vol", "vols", "volumtype", "vq", "vs", "vt", "vu", "w", "wa", "want", "wants", "was", "wasn", "wasnt", "wasn't", "way", "we", "wed", "we'd", "welcome", "well", "we'll", "well-b", "went", "were", "we're", "weren", "werent", "weren't", "we've", "what", "whatever", "what'll", "whats", "what's", "when", "whence", "whenever", "when's", "where", "whereafter", "whereas", "whereby", "wherein", "wheres", "where's", "whereupon", "wherever", "whether", "which", "while", "whim", "whither", "who", "whod", "whoever", "whole", "who'll", "whom", "whomever", "whos", "who's", "whose", "why", "why's", "wi", "widely", "will", "willing", "wish", "with", "within", "without", "wo", "won", "wonder", "wont", "won't", "words", "world", "would", "wouldn", "wouldnt", "wouldn't", "www", "x", "x1", "x2", "x3", "xf", "xi", "xj", "xk", "xl", "xn", "xo", "xs", "xt", "xv", "xx", "y", "y2", "yes", "yet", "yj", "yl", "you", "youd", "you'd", "you'll", "your", "youre", "you're", "yours", "yourself", "yourselves", "you've", "yr", "ys", "yt", "z", "zero", "zi", "zz", "'"])

# %%
# 가사로 부터 추가한 불용어 단어까지 삭제
data['cleaned_lyrics'] = data['cleaned_lyrics'].apply(lambda x: [item for item in x if item not in stop])

# %%
data.head()
# Out:
#          artist                                             lyrics  \
# 0  Elijah Blake  no no\r\ni ain't ever trapped out the bando\r\...
# 1  Elijah Blake  the drinks go down and smoke goes up i feel my...
# 2  Elijah Blake  she don't live on planet earth no more\r\nshe ...
# 3  Elijah Blake  trippin' off that grigio mobbin' lights low\r\...
# 4  Elijah Blake  i see a midnight panther so gallant and so bra...
#
#                  song  label  \
# 0            Everyday  0.626
# 1    Live Till We Die  0.630
# 2       The Otherside  0.240
# 3               Pinot  0.536
# 4  Shadows & Diamonds  0.371
#
#                                                  lem  \
# 0  no no i ain t ever trap out the bando but oh l...
# 1  the drink go down and smoke go up i feel mysel...
# 2  she don t live on planet earth no more she fin...
# 3  trippin  off that grigio mobbin  light low tri...
# 4  i see a midnight panther so gallant and so bra...
#
#                                       cleaned_lyrics
# 0  [trap, bando, lord, wrong, couple, niggas, pla...
# 1  [drink, smoke, feel, care, lose, crowd, yo, sl...
# 2  [live, planet, earth, love, venus, word, space...
# 3  [trippin, grigio, mobbin, light, low, trippin,...
# 4  [midnight, panther, gallant, brave, answer, th...

# %%
def list2str(words):
    return ' '.join(words)

# %%
data['lyrics_str'] = data['cleaned_lyrics'].apply(list2str)

# %%
data
# Out:
#               artist                                             lyrics  \
# 0       Elijah Blake  no no\r\ni ain't ever trapped out the bando\r\...
# 1       Elijah Blake  the drinks go down and smoke goes up i feel my...
# 2       Elijah Blake  she don't live on planet earth no more\r\nshe ...
# 3       Elijah Blake  trippin' off that grigio mobbin' lights low\r\...
# 4       Elijah Blake  i see a midnight panther so gallant and so bra...
# ...              ...                                                ...
# 158348    Adam Green  and we live on borrowed time\r\nbut this heads...
# 158349    Adam Green  frozin in time forever\r\ncarrying that torch ...
# 158350    Adam Green  hard to be a girl. \r\nso nice to be a boy. \r...
# 158351    Adam Green  i want to chose to die\r\nand be buried with a...
# 158352    Adam Green  musical ladders\r\nleaning on mountains\r\nbat...
#
#                       song  label  \
# 0                 Everyday  0.626
# 1         Live Till We Die  0.630
# 2            The Otherside  0.240
# 3                    Pinot  0.536
# 4       Shadows & Diamonds  0.371
# ...                    ...    ...
# 158348     Friends of Mine  0.737
# 158349      Frozen in Time  0.482
# 158350   Hard to Be a Girl  0.733
# 158351         I Wanna Die  0.361
# 158352     Musical Ladders  0.263
#
#                                                       lem  \
# 0       no no i ain t ever trap out the bando but oh l...
# 1       the drink go down and smoke go up i feel mysel...
# 2       she don t live on planet earth no more she fin...
# 3       trippin  off that grigio mobbin  light low tri...
# 4       i see a midnight panther so gallant and so bra...
# ...                                                   ...
# 158348  and we live on borrow time but this headshot s...
# 158349  frozin in time forever carry that torch for so...
# 158350  hard to be a girl. so nice to be a boy. in my ...
# 158351  i want to choose to die and be bury with a rub...
# 158352  musical ladder lean on mountains bath in white...
#
#                                            cleaned_lyrics  \
# 0       [trap, bando, lord, wrong, couple, niggas, pla...
# 1       [drink, smoke, feel, care, lose, crowd, yo, sl...
# 2       [live, planet, earth, love, venus, word, space...
# 3       [trippin, grigio, mobbin, light, low, trippin,...
# 4       [midnight, panther, gallant, brave, answer, th...
# ...                                                   ...
# 158348  [live, borrow, time, headshot, pretty, good, s...
# 158349  [frozin, time, forever, carry, torch, long, he...
# 158350  [hard, girl., nice, boy., room, night., pretty...
# 158351  [choose, die, bury, rubix, cube, sleep, inside...
# 158352  [musical, ladder, lean, mountains, bath, white...
#
#                                                lyrics_str
# 0       trap bando lord wrong couple niggas place gott...
# 1       drink smoke feel care lose crowd yo slow light...
# 2       live planet earth love venus word space time e...
# 3       trippin grigio mobbin light low trippin grigio...
# 4       midnight panther gallant brave answer thunder ...
# ...                                                   ...
# 158348  live borrow time headshot pretty good scheme l...
# 158349  frozin time forever carry torch long hear hear...
# 158350  hard girl. nice boy. room night. pretty site. ...
# 158351  choose die bury rubix cube sleep inside big bl...
# 158352  musical ladder lean mountains bath white laugh...
#
# [158353 rows x 7 columns]

# %%
data.drop(['lyrics'], axis=1, inplace=True) #lyrics열 삭제

# %%
# !pip install NRCLex
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting NRCLex
#   Downloading NRCLex-4.0-py3-none-any.whl (4.4 kB)
# Requirement already satisfied: textblob in /usr/local/lib/python3.8/dist-packages (from NRCLex) (0.15.3)
#   Downloading NRCLex-3.0.0.tar.gz (396 kB)
#      |████████████████████████████████| 396 kB 7.5 MB/s
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.8/dist-packages (from textblob->NRCLex) (3.7)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.8/dist-packages (from nltk>=3.1->textblob->NRCLex) (2022.6.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from nltk>=3.1->textblob->NRCLex) (4.64.1)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk>=3.1->textblob->NRCLex) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from nltk>=3.1->textblob->NRCLex) (1.2.0)
# Building wheels for collected packages: NRCLex
#   Building wheel for NRCLex (setup.py) ... done
#   Created wheel for NRCLex: filename=NRCLex-3.0.0-py3-none-any.whl size=43329 sha256=e82a4e592c159c27609f3222b62f710bc10bf3e2a56d64a6a99cd1a3f8bf5f81
#   Stored in directory: /root/.cache/pip/wheels/83/95/c0/42b43fb15eb48e4f5a67cba8915540cb2783591c59c037a9e5
# Successfully built NRCLex
# Installing collected packages: NRCLex
# Successfully installed NRCLex-3.0.0

# %%
# NRCLex(NRCLexicon)란? 

# 마크 M. 베일리(Mark M. Bailey)가 MIT에서 승인한 PyPI 프로젝트로, 주어진 텍스트의 감정과 감정을 예측한다. 
# 이 패키지는 약 27,000개의 단어를 포함하고 있으며 캐나다 국립 연구 위원회(NRC) 영향 어휘와 
# NLTK 라이브러리의  WordNet 동의어 집합을 기반으로 한다.

# 측정된 감정적 영향은 다음을 포함한다.

# fear
# anger
# anticipation
# trust
# surprise
# positive
# negative
# sadness
# disgust
# joy

# %%
from nrclex import NRCLex

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
data['lyrics_emo']=data['lem'].apply(lambda x : NRCLex(x).raw_emotion_scores)

# %%
data
# Out:
#               artist                song  label  \
# 0       Elijah Blake            Everyday  0.626
# 1       Elijah Blake    Live Till We Die  0.630
# 2       Elijah Blake       The Otherside  0.240
# 3       Elijah Blake               Pinot  0.536
# 4       Elijah Blake  Shadows & Diamonds  0.371
# ...              ...                 ...    ...
# 158348    Adam Green     Friends of Mine  0.737
# 158349    Adam Green      Frozen in Time  0.482
# 158350    Adam Green   Hard to Be a Girl  0.733
# 158351    Adam Green         I Wanna Die  0.361
# 158352    Adam Green     Musical Ladders  0.263
#
#                                                       lem  \
# 0       no no i ain t ever trap out the bando but oh l...
# 1       the drink go down and smoke go up i feel mysel...
# 2       she don t live on planet earth no more she fin...
# 3       trippin  off that grigio mobbin  light low tri...
# 4       i see a midnight panther so gallant and so bra...
# ...                                                   ...
# 158348  and we live on borrow time but this headshot s...
# 158349  frozin in time forever carry that torch for so...
# 158350  hard to be a girl. so nice to be a boy. in my ...
# 158351  i want to choose to die and be bury with a rub...
# 158352  musical ladder lean on mountains bath in white...
#
#                                            cleaned_lyrics  \
# 0       [trap, bando, lord, wrong, couple, niggas, pla...
# 1       [drink, smoke, feel, care, lose, crowd, yo, sl...
# 2       [live, planet, earth, love, venus, word, space...
# 3       [trippin, grigio, mobbin, light, low, trippin,...
# 4       [midnight, panther, gallant, brave, answer, th...
# ...                                                   ...
# 158348  [live, borrow, time, headshot, pretty, good, s...
# 158349  [frozin, time, forever, carry, torch, long, he...
# 158350  [hard, girl., nice, boy., room, night., pretty...
# 158351  [choose, die, bury, rubix, cube, sleep, inside...
# 158352  [musical, ladder, lean, mountains, bath, white...
#
#                                                lyrics_str  \
# 0       trap bando lord wrong couple niggas place gott...
# 1       drink smoke feel care lose crowd yo slow light...
# 2       live planet earth love venus word space time e...
# 3       trippin grigio mobbin light low trippin grigio...
# 4       midnight panther gallant brave answer thunder ...
# ...                                                   ...
# 158348  live borrow time headshot pretty good scheme l...
# 158349  frozin time forever carry torch long hear hear...
# 158350  hard girl. nice boy. room night. pretty site. ...
# 158351  choose die bury rubix cube sleep inside big bl...
# 158352  musical ladder lean mountains bath white laugh...
#
#                                                lyrics_emo
# 0       {'disgust': 6, 'negative': 11, 'positive': 11,...
# 1       {'anger': 1, 'disgust': 1, 'fear': 27, 'negati...
# 2       {'positive': 5, 'trust': 3, 'joy': 1, 'anticip...
# 3       {'joy': 16, 'positive': 23, 'fear': 6, 'surpri...
# 4       {'positive': 14, 'joy': 12, 'trust': 11, 'nega...
# ...                                                   ...
# 158348  {'anticipation': 7, 'joy': 11, 'positive': 11,...
# 158349  {'anticipation': 12, 'fear': 2, 'trust': 6, 'j...
# 158350  {'disgust': 5, 'negative': 5, 'anticipation': ...
# 158351  {'fear': 5, 'negative': 8, 'sadness': 7, 'trus...
# 158352  {'anger': 1, 'anticipation': 8, 'joy': 12, 'po...
#
# [158353 rows x 7 columns]

# %%
data.dtypes
# Out:
# artist             object
# song               object
# label             float64
# lem                object
# cleaned_lyrics     object
# lyrics_str         object
# lyrics_emo         object
# dtype: object

# %%
# 주요 감정 추출
def main_emotion(d):
    k = v = ''
    if d:
        d = {k: v for k, v in d.items() if isinstance(v, (int, float))}
        if d:
            k = max(d, key=d.get)
            v = d[k]
    return pd.Series({'emotion': k, 'value': v})

data = pd.concat([data, data['lyrics_emo'].apply(main_emotion)], axis=1)

# %%
data
# Out:
#               artist                song  label  \
# 0       Elijah Blake            Everyday  0.626
# 1       Elijah Blake    Live Till We Die  0.630
# 2       Elijah Blake       The Otherside  0.240
# 3       Elijah Blake               Pinot  0.536
# 4       Elijah Blake  Shadows & Diamonds  0.371
# ...              ...                 ...    ...
# 158348    Adam Green     Friends of Mine  0.737
# 158349    Adam Green      Frozen in Time  0.482
# 158350    Adam Green   Hard to Be a Girl  0.733
# 158351    Adam Green         I Wanna Die  0.361
# 158352    Adam Green     Musical Ladders  0.263
#
#                                                       lem  \
# 0       no no i ain t ever trap out the bando but oh l...
# 1       the drink go down and smoke go up i feel mysel...
# 2       she don t live on planet earth no more she fin...
# 3       trippin  off that grigio mobbin  light low tri...
# 4       i see a midnight panther so gallant and so bra...
# ...                                                   ...
# 158348  and we live on borrow time but this headshot s...
# 158349  frozin in time forever carry that torch for so...
# 158350  hard to be a girl. so nice to be a boy. in my ...
# 158351  i want to choose to die and be bury with a rub...
# 158352  musical ladder lean on mountains bath in white...
#
#                                            cleaned_lyrics  \
# 0       [trap, bando, lord, wrong, couple, niggas, pla...
# 1       [drink, smoke, feel, care, lose, crowd, yo, sl...
# 2       [live, planet, earth, love, venus, word, space...
# 3       [trippin, grigio, mobbin, light, low, trippin,...
# 4       [midnight, panther, gallant, brave, answer, th...
# ...                                                   ...
# 158348  [live, borrow, time, headshot, pretty, good, s...
# 158349  [frozin, time, forever, carry, torch, long, he...
# 158350  [hard, girl., nice, boy., room, night., pretty...
# 158351  [choose, die, bury, rubix, cube, sleep, inside...
# 158352  [musical, ladder, lean, mountains, bath, white...
#
#                                                lyrics_str  \
# 0       trap bando lord wrong couple niggas place gott...
# 1       drink smoke feel care lose crowd yo slow light...
# 2       live planet earth love venus word space time e...
# 3       trippin grigio mobbin light low trippin grigio...
# 4       midnight panther gallant brave answer thunder ...
# ...                                                   ...
# 158348  live borrow time headshot pretty good scheme l...
# 158349  frozin time forever carry torch long hear hear...
# 158350  hard girl. nice boy. room night. pretty site. ...
# 158351  choose die bury rubix cube sleep inside big bl...
# 158352  musical ladder lean mountains bath white laugh...
#
#                                                lyrics_emo       emotion value
# 0       {'disgust': 6, 'negative': 11, 'positive': 11,...      negative    11
# 1       {'anger': 1, 'disgust': 1, 'fear': 27, 'negati...      negative    30
# 2       {'positive': 5, 'trust': 3, 'joy': 1, 'anticip...      negative    10
# 3       {'joy': 16, 'positive': 23, 'fear': 6, 'surpri...      positive    23
# 4       {'positive': 14, 'joy': 12, 'trust': 11, 'nega...      positive    14
# ...                                                   ...           ...   ...
# 158348  {'anticipation': 7, 'joy': 11, 'positive': 11,...      negative    12
# 158349  {'anticipation': 12, 'fear': 2, 'trust': 6, 'j...  anticipation    12
# 158350  {'disgust': 5, 'negative': 5, 'anticipation': ...      positive    10
# 158351  {'fear': 5, 'negative': 8, 'sadness': 7, 'trus...      negative     8
# 158352  {'anger': 1, 'anticipation': 8, 'joy': 12, 'po...      positive    14
#
# [158353 rows x 9 columns]

# %%
data.drop(['label', 'lem', 'value'], axis=1, inplace=True)
# 필요 없는 열들은 제거

# %%
data
# Out:
#               artist                song  \
# 0       Elijah Blake            Everyday
# 1       Elijah Blake    Live Till We Die
# 2       Elijah Blake       The Otherside
# 3       Elijah Blake               Pinot
# 4       Elijah Blake  Shadows & Diamonds
# ...              ...                 ...
# 158348    Adam Green     Friends of Mine
# 158349    Adam Green      Frozen in Time
# 158350    Adam Green   Hard to Be a Girl
# 158351    Adam Green         I Wanna Die
# 158352    Adam Green     Musical Ladders
#
#                                            cleaned_lyrics  \
# 0       [trap, bando, lord, wrong, couple, niggas, pla...
# 1       [drink, smoke, feel, care, lose, crowd, yo, sl...
# 2       [live, planet, earth, love, venus, word, space...
# 3       [trippin, grigio, mobbin, light, low, trippin,...
# 4       [midnight, panther, gallant, brave, answer, th...
# ...                                                   ...
# 158348  [live, borrow, time, headshot, pretty, good, s...
# 158349  [frozin, time, forever, carry, torch, long, he...
# 158350  [hard, girl., nice, boy., room, night., pretty...
# 158351  [choose, die, bury, rubix, cube, sleep, inside...
# 158352  [musical, ladder, lean, mountains, bath, white...
#
#                                                lyrics_str  \
# 0       trap bando lord wrong couple niggas place gott...
# 1       drink smoke feel care lose crowd yo slow light...
# 2       live planet earth love venus word space time e...
# 3       trippin grigio mobbin light low trippin grigio...
# 4       midnight panther gallant brave answer thunder ...
# ...                                                   ...
# 158348  live borrow time headshot pretty good scheme l...
# 158349  frozin time forever carry torch long hear hear...
# 158350  hard girl. nice boy. room night. pretty site. ...
# 158351  choose die bury rubix cube sleep inside big bl...
# 158352  musical ladder lean mountains bath white laugh...
#
#                                                lyrics_emo       emotion
# 0       {'disgust': 6, 'negative': 11, 'positive': 11,...      negative
# 1       {'anger': 1, 'disgust': 1, 'fear': 27, 'negati...      negative
# 2       {'positive': 5, 'trust': 3, 'joy': 1, 'anticip...      negative
# 3       {'joy': 16, 'positive': 23, 'fear': 6, 'surpri...      positive
# 4       {'positive': 14, 'joy': 12, 'trust': 11, 'nega...      positive
# ...                                                   ...           ...
# 158348  {'anticipation': 7, 'joy': 11, 'positive': 11,...      negative
# 158349  {'anticipation': 12, 'fear': 2, 'trust': 6, 'j...  anticipation
# 158350  {'disgust': 5, 'negative': 5, 'anticipation': ...      positive
# 158351  {'fear': 5, 'negative': 8, 'sadness': 7, 'trus...      negative
# 158352  {'anger': 1, 'anticipation': 8, 'joy': 12, 'po...      positive
#
# [158353 rows x 6 columns]

# %% [markdown]
# lyrics에 따른 song 군집화

# %%
import seaborn as sns
import plotly.express as px 
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from sklearn.metrics import euclidean_distances
from scipy.spatial.distance import cdist

import warnings
warnings.filterwarnings("ignore")

# %%
df = data[['song', 'lyrics_emo', 'emotion']]

# %%
rows=[]
emotions = df['lyrics_emo']
for song, main_e, row in zip(df['song'], df['emotion'], emotions):
    row['song'] = song
    row['emotion'] = main_e
    rows.append(row)
    
emotion_df = pd.DataFrame(rows)
emotion_df
# Out:
#         disgust  negative  positive  trust  anticipation  fear  anger   joy  \
# 0           6.0      11.0      11.0    9.0           8.0   8.0    9.0   3.0
# 1           1.0      30.0       8.0    9.0           3.0  27.0    1.0   5.0
# 2           6.0      10.0       5.0    3.0           3.0   2.0    6.0   1.0
# 3           5.0      11.0      23.0    9.0           6.0   6.0    6.0  16.0
# 4           4.0       6.0      14.0   11.0           NaN   1.0    1.0  12.0
# ...         ...       ...       ...    ...           ...   ...    ...   ...
# 158348      2.0      12.0      11.0    8.0           7.0   4.0    1.0  11.0
# 158349      1.0       2.0       8.0    6.0          12.0   2.0    1.0   4.0
# 158350      5.0       5.0      10.0    6.0           6.0   2.0    3.0   4.0
# 158351      5.0       8.0       8.0    3.0           2.0   5.0    2.0   3.0
# 158352      1.0       5.0      14.0    9.0           8.0   1.0    1.0  12.0
#
#         surprise  sadness                song       emotion
# 0            8.0      6.0            Everyday      negative
# 1            2.0     27.0    Live Till We Die      negative
# 2            8.0      6.0       The Otherside      negative
# 3            2.0      5.0               Pinot      positive
# 4            2.0      3.0  Shadows & Diamonds      positive
# ...          ...      ...                 ...           ...
# 158348       9.0      8.0     Friends of Mine      negative
# 158349       3.0      1.0      Frozen in Time  anticipation
# 158350       2.0      2.0   Hard to Be a Girl      positive
# 158351       3.0      7.0         I Wanna Die      negative
# 158352       9.0      2.0     Musical Ladders      positive
#
# [158353 rows x 12 columns]

# %%
# 데이터프레임 컬럼 순서 변경 - 'song'열이 맨 앞으로 오게 했습니다-
emotion_df=emotion_df[['song','emotion','disgust', 'negative', 'positive', 'trust', 'anticipation', 
                       'fear','anger', 'joy', 'surprise', 'sadness']]

# %%
emotion_df
# Out:
#                       song       emotion  disgust  negative  positive  trust  \
# 0                 Everyday      negative      6.0      11.0      11.0    9.0
# 1         Live Till We Die      negative      1.0      30.0       8.0    9.0
# 2            The Otherside      negative      6.0      10.0       5.0    3.0
# 3                    Pinot      positive      5.0      11.0      23.0    9.0
# 4       Shadows & Diamonds      positive      4.0       6.0      14.0   11.0
# ...                    ...           ...      ...       ...       ...    ...
# 158348     Friends of Mine      negative      2.0      12.0      11.0    8.0
# 158349      Frozen in Time  anticipation      1.0       2.0       8.0    6.0
# 158350   Hard to Be a Girl      positive      5.0       5.0      10.0    6.0
# 158351         I Wanna Die      negative      5.0       8.0       8.0    3.0
# 158352     Musical Ladders      positive      1.0       5.0      14.0    9.0
#
#         anticipation  fear  anger   joy  surprise  sadness
# 0                8.0   8.0    9.0   3.0       8.0      6.0
# 1                3.0  27.0    1.0   5.0       2.0     27.0
# 2                3.0   2.0    6.0   1.0       8.0      6.0
# 3                6.0   6.0    6.0  16.0       2.0      5.0
# 4                NaN   1.0    1.0  12.0       2.0      3.0
# ...              ...   ...    ...   ...       ...      ...
# 158348           7.0   4.0    1.0  11.0       9.0      8.0
# 158349          12.0   2.0    1.0   4.0       3.0      1.0
# 158350           6.0   2.0    3.0   4.0       2.0      2.0
# 158351           2.0   5.0    2.0   3.0       3.0      7.0
# 158352           8.0   1.0    1.0  12.0       9.0      2.0
#
# [158353 rows x 12 columns]

# %%
# 수치가 0인 감정선은 Nan으로 나타나 이를 0으로 변경해줍니다.
emotion_df.fillna(0, inplace=True)

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %% [markdown]
# #Clustering Emotion with K-Means (감정으로 군집화)

# %%
cluster_pipeline = Pipeline([('scaler', StandardScaler()), ('kmeans', KMeans(n_clusters=10))])
X = emotion_df.select_dtypes(np.number)
cluster_pipeline.fit(X)
emotion_df['cluster'] = cluster_pipeline.predict(X)

# %%
# Visualizing the Clusters with t-SNE

from sklearn.manifold import TSNE

tsne_pipeline = Pipeline([('scaler', StandardScaler()), ('tsne', TSNE(n_components=2, verbose=1))])
emotion_embedding = tsne_pipeline.fit_transform(X)
projection = pd.DataFrame(columns=['x', 'y'], data=emotion_embedding)
projection['emotion'] = emotion_df['emotion']
projection['cluster'] = emotion_df['cluster']

fig = px.scatter(
    projection, x='x', y='y', color='cluster', hover_data=['x', 'y', 'emotion'])
fig.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
#verbose  # 함수 수행시 발생하는 상세한 정보들 표준 출력으로 자세히 내보낼 것인가 
# 0 -> 출력하지 X, 1 -> 자세히, 2 -> 함축적인 정보만 출력

# %% [markdown]
# #Clustering Songs with K-means (노래 군집화)

# %%
song_cluster_pipeline = Pipeline([('scaler', StandardScaler()), 
                                  ('kmeans', KMeans(n_clusters=20,  #20개로 군집화
                                   verbose=False)) # 함수 수행시 발생하는 상세한 정보들 표준 출력으로 자세히 내보낼 것인가 -> False
                                 ], verbose=False)

X = emotion_df.select_dtypes(np.number)
number_cols = list(X.columns)
song_cluster_pipeline.fit(X)
song_cluster_labels = song_cluster_pipeline.predict(X)
emotion_df['cluster_label'] = song_cluster_labels

# %%
# Visualizing the Clusters with PCA

from sklearn.decomposition import PCA

pca_pipeline = Pipeline([('scaler', StandardScaler()), ('PCA', PCA(n_components=2))])
emotion_embedding = pca_pipeline.fit_transform(X)
projection = pd.DataFrame(columns=['x', 'y'], data=emotion_embedding)
projection['title'] = emotion_df['song']
projection['cluster'] = emotion_df['emotion']

fig = px.scatter(
    projection, x='x', y='y', color='cluster', hover_data=['x', 'y', 'title'])
fig.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# 노래 데이터셋 분류 체크

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.feature_extraction.text import CountVectorizer
from sklearn.pipeline import Pipeline

from sklearn.model_selection import train_test_split
from sklearn.svm import LinearSVC
from sklearn.metrics import classification_report, f1_score
from sklearn.metrics import accuracy_score

# %%
X = data['lyrics_str']
y = emotion_df['emotion']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2022)

# %%
X
# Out:
# 0         trap bando lord wrong couple niggas place gott...
# 1         drink smoke feel care lose crowd yo slow light...
# 2         live planet earth love venus word space time e...
# 3         trippin grigio mobbin light low trippin grigio...
# 4         midnight panther gallant brave answer thunder ...
#                                 ...
# 158348    live borrow time headshot pretty good scheme l...
# 158349    frozin time forever carry torch long hear hear...
# 158350    hard girl. nice boy. room night. pretty site. ...
# 158351    choose die bury rubix cube sleep inside big bl...
# 158352    musical ladder lean mountains bath white laugh...
# Name: lyrics_str, Length: 158353, dtype: object

# %%
y
# Out:
# 0             negative
# 1             negative
# 2             negative
# 3             positive
# 4             positive
#               ...
# 158348        negative
# 158349    anticipation
# 158350        positive
# 158351        negative
# 158352        positive
# Name: emotion, Length: 158353, dtype: object

# %%
text_clf = Pipeline([('tfidf',TfidfVectorizer()),('clf',LinearSVC())])
text_clf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()), ('clf', LinearSVC())])

# %%
pred = text_clf.predict(X_test)

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#                    0.69      0.83      0.75       483
#        anger       0.68      0.26      0.38       355
# anticipation       0.81      0.68      0.74      2382
#      disgust       0.67      0.12      0.21        96
#         fear       0.76      0.36      0.49       900
#          joy       0.75      0.40      0.52      1252
#     negative       0.79      0.84      0.81      8065
#     positive       0.83      0.92      0.87     16528
#      sadness       0.83      0.54      0.65       557
#     surprise       0.82      0.46      0.59       348
#        trust       0.72      0.33      0.46       705
#
#     accuracy                           0.81     31671
#    macro avg       0.76      0.52      0.59     31671
# weighted avg       0.80      0.81      0.80     31671

# %%
acc=accuracy_score(y_test, pred)*100
print("분류 정확도 : {:.2f} %".format(acc))
# Out:
# 분류 정확도 : 80.92 %
